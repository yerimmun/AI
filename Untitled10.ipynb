# %% [markdown]
# <a href="https://colab.research.google.com/github/yerimmun/AI/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as pit

# %%
values = [10, 30, 20, 40, 30]

# %%
pit.plot(values)

# %%
items = ['a', 'b', 'c', 'd','e']
values = [10, 30, 20, 40, 30]

# %%
pit.bar(items, values)
# Out:
# <BarContainer object of 5 artists>

# %%
import matplotlib.pyplot as plt
data = [1, 2, 3, 4]
plt.plot(data, marker='o', color='g')
plt.grid(True)
plt.title('Teamperature')
plt.savefig('차트예시.png')
plt.show()
