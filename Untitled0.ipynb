# %% [markdown]
# <a href="https://colab.research.google.com/github/yerimmun/AI/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache-fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 20 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (7,794 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6a22c877-9829-4bbd-9fee-1566ae6127ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a22c877-9829-4bbd-9fee-1566ae6127ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 상도동2020아파트.xlsx to 상도동2020아파트.xlsx
# ...

# %%
import pandas as pd

# %%
aptData = pd.read_excel('상도동2020아파트.xlsx')

# %%
aptData
# Out:
#                시군구     번지   본번  부번             단지명      전용면적         평수  \
# 0    서울특별시 동작구 상도동  323-4  323   4         (323-4)  106.5100  32.275758
# 1    서울특별시 동작구 상도동    903  903   0     e편한세상상도노빌리티   59.7827  18.115970
# 2    서울특별시 동작구 상도동    903  903   0     e편한세상상도노빌리티   59.9173  18.156758
# 3    서울특별시 동작구 상도동    903  903   0     e편한세상상도노빌리티   59.9173  18.156758
# 4    서울특별시 동작구 상도동    903  903   0     e편한세상상도노빌리티   59.9173  18.156758
# ..             ...    ...  ...  ..             ...       ...        ...
# 783  서울특별시 동작구 상도동    533  533   0  힐스테이트 상도 프레스티지   84.9510  25.742727
# 784  서울특별시 동작구 상도동    533  533   0  힐스테이트 상도 프레스티지   84.8840  25.722424
# 785  서울특별시 동작구 상도동    533  533   0  힐스테이트 상도 프레스티지   84.8840  25.722424
# 786  서울특별시 동작구 상도동    533  533   0  힐스테이트 상도 프레스티지   84.8840  25.722424
# 787  서울특별시 동작구 상도동    533  533   0  힐스테이트 상도 프레스티지   84.9510  25.742727
#
#        계약년월  계약일    거래금액   층  건축년도        도로명 거래유형 중개사소재지
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
sns.relplot(data=aptData, x='평수', y='거래금액')

# %%
sns.relplot(data=aptData, x='층', y='거래금액')

# %%
sns.relplot(data=aptData, x='건축년도', y='거래금액', hue='평수')
