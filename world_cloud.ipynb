# %% [markdown]
# <a href="https://colab.research.google.com/github/yerimmun/AI/blob/main/world_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = 'System Ai Data information Ai Science Ai Analysis Data'

# %%
from wordcloud import WordCloud

# %%
wc_output = WordCloud(width=1500, height=1000).generate(text)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(wc_output)
plt.show()
